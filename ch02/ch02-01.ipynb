# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/colab/images/aa.jpg')

# %%
plt.imshow(img)

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
cv2.split(RGB_img.shape)
# Out:
# (array([[512.],
#         [512.],
#         [  3.]]),)

# %%
print(RGB_img)
# Out:
# [[[220 139 118]
#   [220 137 119]
#   [221 136 133]
#   ...
#   [229 147 123]
#   [222 129 112]
#   [201  98  93]]
#
#  [[225 137 125]
#   [225 137 127]
#   [224 136 134]
#   ...
#   [229 148 121]
#   [222 130 107]
#   [200  99  87]]
#
#  [[227 137 126]
#   [227 137 128]
#   [222 137 132]
#   ...
#   [232 148 122]
#   [222 129 111]
#   [201  98  89]]
#
#  ...
#
#  [[ 85  18  61]
#   [ 83  18  60]
#   [ 91  26  58]
#   ...
#   [171  74  83]
#   [173  69  78]
#   [176  61  78]]
#
#  [[ 82  21  55]
#   [ 82  22  56]
#   [ 97  30  61]
#   ...
#   [179  70  76]
#   [182  71  80]
#   [184  75  81]]
#
#  [[ 86  21  61]
#   [ 83  21  58]
#   [ 96  31  63]
#   ...
#   [179  69  78]
#   [181  71  80]
#   [187  74  80]]]
